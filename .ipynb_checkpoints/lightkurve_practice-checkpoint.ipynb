# %%
from lightkurve import search_targetpixelfile
import matplotlib.pyplot as plt
pixelfile = search_targetpixelfile("KIC 8462852", quarter=16).download()

# %%
pixelfile.plot()
# Out:
# <Axes: title={'center': 'Target ID: 8462852, Cadence: 66713'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
lc = pixelfile.to_lightcurve(aperture_mask='all')

# %%
lc.time, lc.flux
# Out:
# (<Time object: scale='tdb' format='bkjd' value=[1472.11777934 1472.13821223 1472.15864492 ... 1557.91762194 1557.9380561
#   1557.95849016]>,
#  <Quantity [258645.03, 258660.05, 258690.08, ..., 258948.84, 258884.66,
#             258865.6 ] electron / s>)

# %%
lc.plot()
plt.show()

# %% [markdown]
# ##### Search for a new star pixelfile

# %%
new_pixelfile = search_targetpixelfile("KIC 6922244", quarter=4).download_all()

# %%
star = new_pixelfile.to_lightcurve
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/alexeirusu/Desktop/LIGHTCURVE/lightkurve_practice.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/Users/alexeirusu/Desktop/LIGHTCURVE/lightkurve_practice.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> star = new_pixelfile.to_lightcurve
#
# AttributeError: 'TargetPixelFileCollection' object has no attribute 'to_lightcurve'

# %%
star.plot()
plt.show()

# %%
flat_star = star.flatten(window_length=401)
flat_star.plot()
plt.show()

# %%
folded_star = flat_star.fold(period=3.525)
folded_star.plot()
plt.show()

# %%
import numpy as np
periodogram = flat_star.to_periodogram(method="bls", period=np.arange(1, 10, 0.001))
periodogram.plot()
plt.show()

# %%
best_fit_period = periodogram.period_at_max_power
print('Best fit period: {:.3f}'.format(best_fit_period))
# Out:
# Best fit period: 3.522 d
