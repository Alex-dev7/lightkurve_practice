# %%
import lightkurve as lk
from lightkurve import TessTargetPixelFile
import matplotlib.pyplot as plt

# %%
path = '/Users/alexeirusu/Desktop/LIGHTCURVE/hlsp_tess-spoc_tess_phot_0000000058998044-s0044_tess_v1_tp.fits'
tpf = TessTargetPixelFile(path)

# %%
# %matplotlib inline
tpf.plot()
# Out:
# <Axes: title={'center': 'Target ID: 58998044, Cadence: 183274'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
lc = tpf.to_lightcurve()

# %%
lc.plot()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc_flatten = lc.flatten()
# lc_flatten.scatter(s=0.5)

# %%
lc_bin = lc_flatten.bin(15 / 24 / 60)
lc_bin.plot(linewidth=0, marker='.')
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>
